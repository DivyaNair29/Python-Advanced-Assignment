# %% [markdown]
# Q1. If you have any, what are your choices for increasing the comparison between different figures on
# the same graph?
#
# Ans: Scatter plot.

# %% [markdown]
# Q2. Can you explain the benefit of compound interest over a higher rate of interest that does not
# compound after reading this chapter?
#
# Ans:  Compound interest causes one's wealth to grow faster. It makes a sum of money grow at a faster rate than simple interest because one will earn returns on the money other invest, as well as on returns at the end of every compounding period. This means that one don't have to put away as much money to reach others goals.

# %% [markdown]
# Q3. What is a histogram, exactly? Name a numpy method for creating such a graph.
#
# Ans:  A histogram is a graphical representation of data points organized into user-specified ranges. It displays numerical data by grouping data into "bins" of equal width.
# numpy.histogram() is used for creating such graph.

# %% [markdown]
# Q4. If necessary, how do you change the aspect ratios between the X and Y axes?

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
x = np.arange(0,math.pi,0.01)
y = np.sin(20*x)

plt.figure(figsize = (5,4))
plt.plot(x,y)
plt.title('plot with undefined aspect ratio')
plt.show()

# %%
plt.figure(figsize=(10,3)) #fig size same as before
ax = plt.gca() #we first need to get the axis handle
ax.set_aspect(1.5) #sets the height to width ratio to 1.5. 
#Use help(ax.set_aspect) for more options.

plt.plot(x,y)
plt.title('plot with Fixed aspect ratio')
plt.show()

# %% [markdown]
# Q5. Compare and contrast the three types of array multiplication between two numpy arrays: dot
# product, outer product, and regular multiplication of two numpy arrays.

# %%
import numpy as np


# vector v1 of dimension (2, 2)
v1 = np.array([[1, 2], [1, 2]])

# vector v2 of dimension (2, 2)
v2 = np.array([[1, 2], [1, 2]])

print("vector multiplication")
print(np.dot(v1, v2))
print("outer multiplication")
print(np.outer(v1, v2))
print("\nElementwise multiplication of two vector")
print(v1 * v2)
# Out:
# vector multiplication
# [[3 6]
#  [3 6]]
# outer multiplication
# [[1 2 1 2]
#  [2 4 2 4]
#  [1 2 1 2]
#  [2 4 2 4]]
#
# Elementwise multiplication of two vector
# [[1 4]
#  [1 4]]

# %% [markdown]
# Q6. Before you buy a home, which numpy function will you use to measure your monthly mortgage
# payment?
#
# Ans: np.pmt()

# %% [markdown]
# Q7. Can string data be stored in numpy arrays? If so, list at least one restriction that applies to this
# data.
#
# Ans: Yes, string data can be stored in numpy arrays, but we can store string and then we can use arbitary length at a place of missing values in given array. Generally if they are all of same length it is preferred.
